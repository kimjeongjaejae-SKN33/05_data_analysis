# %% [markdown]
# # DataFrame
# - 행열을 가진 2차원 자료구조
# - 여러개의 Series 묶음 자료형

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## DataFrame 생성

# %%
# dict -> df 생성
data = {"one": [1.0, 2.0, 3.0], "two": [10, 20, 30], "three": 99}

# dict 의 각 item이 하나의 Series로 처리됨
df = pd.DataFrame(data)
print(df['one'])
df
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# Name: one, dtype: float64
#    one  two  three
# 0  1.0   10     99
# 1  2.0   20     99
# 2  3.0   30     99

# %%
# 여러 개의 dict -> dataframe
data = [{
    "a": 10,
    "b": 20,
}, {
    "a": 30,
    "b": 40,
    "c": 50,
}]

# 하나의 dict -> 하나의 레코드, key는 컬럼으로 처리
df = pd.DataFrame(data)
df # 0번행 C NaN
# Out:
#     a   b     c
# 0  10  20   NaN
# 1  30  40  50.0

# %%
# ndarray -> df
arr = np.arange(9).reshape(3,3)
df = pd.DataFrame(arr,columns=('a','b','c'), index = ['1일', '2일', '3일'])
df
# Out:
#     a  b  c
# 1일  0  1  2
# 2일  3  4  5
# 3일  6  7  8

# %%
# ser -> df
name_ser = pd.Series(['홍길동', '이순신', '강감찬'])
age_ser = pd.Series([20, 25, 30])
df = pd.DataFrame({"name" : name_ser, "age" : age_ser})
df
# Out:
#   name  age
# 0  홍길동   20
# 1  이순신   25
# 2  강감찬   30

# %%
# tuple(record) -> dataframe
# 하나의 객체

data = [
    ('홍길동', 20),
    ('이순신', 30),
    ('논개', 43),
]
df = pd.DataFrame.from_records(data, columns=['이름', '나이'])
df
# Out:
#     이름  나이
# 0  홍길동  20
# 1  이순신  30
# 2   논개  43

# %% [markdown]
# ## DataFrame 속성

# %%
data = {
    'Bank client ID':[1, 2, 3, 4],
    'Bank Client Name':['Laila Aly', 'Kate Steve', 'Nicole Mitch', 'Francis Morris'],
    'Net worth [$]':[35000, 3000, 100000, 2000],
    'Years with bank':[4, 7, 10, 15]
}
df = pd.DataFrame(data)
df
# Out:
#    Bank client ID Bank Client Name  Net worth [$]  Years with bank
# 0               1        Laila Aly          35000                4
# 1               2       Kate Steve           3000                7
# 2               3     Nicole Mitch         100000               10
# 3               4   Francis Morris           2000               15

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Bank client ID    4 non-null      int64
#  1   Bank Client Name  4 non-null      str
#  2   Net worth [$]     4 non-null      int64
#  3   Years with bank   4 non-null      int64
# dtypes: int64(3), str(1)
# memory usage: 305.0 bytes
#        Bank client ID  Net worth [$]  Years with bank
# count        4.000000       4.000000         4.000000
# mean         2.500000   35000.000000         9.000000
# std          1.290994   45963.753836         4.690416
# min          1.000000    2000.000000         4.000000
# 25%          1.750000    2750.000000         6.250000
# 50%          2.500000   19000.000000         8.500000
# 75%          3.250000   51250.000000        11.250000
# max          4.000000  100000.000000        15.000000

# %%
print(df.index)
print(df.columns)
# Out:
# RangeIndex(start=0, stop=4, step=1)
# Index(['Bank client ID', 'Bank Client Name', 'Net worth [$]',
#        'Years with bank'],
#       dtype='str')

# %%
print(df.dtypes)
# Out:
# Bank client ID      int64
# Bank Client Name      str
# Net worth [$]       int64
# Years with bank     int64
# dtype: object

# %% [markdown]
# ## DataFrame 메서드

# %%
# head(n), tail(n): 맨 위/밑 n 개 조회

# %%
# value_counts(): 유일값 분포 확인
df['Years with bank'].value_counts()
# Out:
# Years with bank
# 4     1
# 7     1
# 10    1
# 15    1
# Name: count, dtype: int64

# %%
df
# Out:
#    Bank client ID Bank Client Name  Net worth [$]  Years with bank
# 0               1        Laila Aly          35000                4
# 1               2       Kate Steve           3000                7
# 2               3     Nicole Mitch         100000               10
# 3               4   Francis Morris           2000               15

# %%
# index 재지정 : 특정 컬럼을 index로 지정
df = df.set_index("Bank client ID")
df
# Out:
#                Bank Client Name  Net worth [$]  Years with bank
# Bank client ID
# 1                     Laila Aly          35000                4
# 2                    Kate Steve           3000                7
# 3                  Nicole Mitch         100000               10
# 4                Francis Morris           2000               15

# %% [markdown]
# ## 조회
# - 행열조회
#     - df.iloc[인덱스]
#     - df.loc[라벨]
# - 열조회
#     - df[컬럼명]

# %%
dicts = [
    {'name' : '홍길동', 'job' : '강사', 'age' : 33},
    {'name' : '신사임당', 'age' : 44, 'job' : '영업사원'},
    {'name' : '이순신', 'age' : 38, 'job' : '장군'},
    {'name' : '논개', 'age' : 25, 'job' : '개발'},
    {'name' : '강감찬', 'age' : 47, 'job' : '교수'},
]
df = pd.DataFrame(dicts)
df
# Out:
#    name   job  age
# 0   홍길동    강사   33
# 1  신사임당  영업사원   44
# 2   이순신    장군   38
# 3    논개    개발   25
# 4   강감찬    교수   47

# %% [markdown]
# ### iloc (인덱스 위치)

# %%
# 홍길동 행 조회
print(df.iloc[0])
print(type(df.iloc[0])) # Series, df에서 한 행 또는 한 열은 Series 타입이다!
print(df.iloc[0].index)
print(df.iloc[0].name) # df의 인덱스 == ser의 이름
# Out:
# name    홍길동
# job      강사
# age      33
# Name: 0, dtype: object
# <class 'pandas.Series'>
# Index(['name', 'job', 'age'], dtype='str')
# 0

# %%
# 슬라이싱 지원
df2 = df.iloc[0:2] # 0,1 행 df 반환
print(type(df2))
df2
# Out:
# <class 'pandas.DataFrame'>
#    name   job  age
# 0   홍길동    강사   33
# 1  신사임당  영업사원   44

# %%
# fancy indexing 지원
df.iloc[[0,2]]
# Out:
#   name job  age
# 0  홍길동  강사   33
# 2  이순신  장군   38

# %%
# 단일 값  조회
print(df.iloc[0,1])

# 여러 행 조회
df.iloc[:2, 1]
# Out:
# 강사
# 0      강사
# 1    영업사원
# Name: job, dtype: str

# %%
df2 = df.iloc[:2, :2]
print(type(df2))
df2
# Out:
# <class 'pandas.DataFrame'>
#    name   job
# 0   홍길동    강사
# 1  신사임당  영업사원

# %% [markdown]
# ### loc
# 인데스라벨을 통해 조회

# %%
# index 명 지정 == 레이블링(labeling)
df.index = ['client1', 'client2', 'client3', 'client4', 'client5']
df
# Out:
#          name   job  age
# client1   홍길동    강사   33
# client2  신사임당  영업사원   44
# client3   이순신    장군   38
# client4    논개    개발   25
# client5   강감찬    교수   47

# %%
print(type(df.loc['client4']))
df.loc['client4']
# Out:
# <class 'pandas.Series'>
# name    논개
# job     개발
# age     25
# Name: client4, dtype: object

# %%
# df.loc[3] #keyError

# %% [markdown]
# # loc 슬라이싱은 end 값을 포함한다!

# %%
# loc를 이용한 컬럼 단일 값 조회
df.loc['client2', 'job']

# loc를 이용한 슬라이싱
print(df.loc['client2' : 'client4'])
print(df.loc['client2' : 'client4', 'job'])
print(df.loc['client2' : 'client4', 'job':])
# Out:
#          name   job  age
# client2  신사임당  영업사원   44
# client3   이순신    장군   38
# client4    논개    개발   25
# client2    영업사원
# client3      장군
# client4      개발
# Name: job, dtype: str
#           job  age
# client2  영업사원   44
# client3    장군   38
# client4    개발   25

# %% [markdown]
# ### 컬럼라벨

# %%
# df['컬럼명'] : 해당 컬럼 시리즈 변환
df['name']
# Out:
# client1     홍길동
# client2    신사임당
# client3     이순신
# client4      논개
# client5     강감찬
# Name: name, dtype: str

# %%
# 컬럼 라벨 fancy 인덱싱
df[['name', 'job']]
# Out:
#          name   job
# client1   홍길동    강사
# client2  신사임당  영업사원
# client3   이순신    장군
# client4    논개    개발
# client5   강감찬    교수

# %%
# loc + 컬럼 라벨
print(df['name'] == '이순신')
print(df.loc[df['name'] == '이순신'])
# Out:
# client1    False
# client2    False
# client3     True
# client4    False
# client5    False
# Name: name, dtype: bool
#         name job  age
# client3  이순신  장군   38

# %%
# boolean indexing (비교 연산) -> GIT 비교
print(df['age'] > 30)
df[df['age']>30]
# Out:
# client1     True
# client2     True
# client3     True
# client4    False
# client5     True
# Name: age, dtype: bool
#          name   job  age
# client1   홍길동    강사   33
# client2  신사임당  영업사원   44
# client3   이순신    장군   38
# client5   강감찬    교수   47

# %%
# 30세 미만, 개발 직종을 갖는 행 조회
df.loc[ (df['age'] < 30) & (df['job'] == '개발') ]
# Out:
#         name job  age
# client4   논개  개발   25

# %%
# - 이름에 '신'이 들어가거나 나이가 40대이상 조회
df[(df['age'] >= 40) | (df['name'].str.contains('신'))]
# Out:
#          name   job  age
# client2  신사임당  영업사원   44
# client3   이순신    장군   38
# client5   강감찬    교수   47

# %% [markdown]
# ## 행 추가/삭제

# %%
students = [
    {'name': '홍길동', 'midterm': 95, 'final': 85},
    {'name': '신사임당', 'midterm': 85, 'final': 80},
    {'name': '이순신', 'midterm': 10, 'final': 30}
]
df = pd.DataFrame(students)
df
# Out:
#    name  midterm  final
# 0   홍길동       95     85
# 1  신사임당       85     80
# 2   이순신       10     30

# %%
# 중복되지 않는 인덱스에 한 행(Series 타입) 추가(대입)
next_index = len(df)
df.loc[next_index] = pd.Series({'name': '강감찬', 'midterm': 88})
# 추가된 행에 final 컬럼값 누락 -> NaN 결측치
df
# Out:
#    name  midterm  final
# 0   홍길동       95   85.0
# 1  신사임당       85   80.0
# 2   이순신       10   30.0
# 3   강감찬       88    NaN
# 4   강감찬       88    NaN
# 5   강감찬       88    NaN

# %%
# 중복된 인덱스에 한 행(Series 타입) 추가(대입)
next_index = 3
df.loc[next_index] = pd.Series({'name': '율곡이이', 'midterm': 88, 'fianl' : 90})
df
# Out:
#    name  midterm  final
# 0   홍길동       95   85.0
# 1  신사임당       85   80.0
# 2   이순신       10   30.0
# 3  율곡이이       88    NaN
# 4   강감찬       88    NaN
# 5   강감찬       88    NaN

# %%
# 행 삭제 -> 원본 유지
# display(df =df.drop(3))
# display(df)

df = df.drop(3)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 5
#       1 # 행 삭제 -> 원본 유지
#       2 # display(df =df.drop(3))
#       3 # display(df)
#       4
# ----> 5 df = df.drop(3)
#       6 df
#
# File ~\miniforge3\envs\pystudy_env\Lib\site-packages\pandas\core\frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6142 def drop(
#    6143     self,
#    6144     labels: IndexLabel | ListLike = None,
#    (...)   6151     errors: IgnoreRaise = "raise",
#    6152 ) -> DataFrame | None:
#    6153     """
#    6154     Drop specified labels from rows or columns.
#    6155
#    (...)   6298             weight  1.0     0.8
#    6299     """
# -> 6300     return super().drop(
#    6301         labels=labels,
#    6302         axis=axis,
#    6303         index=index,
#    6304         columns=columns,
#    6305         level=level,
#    6306         inplace=inplace,
#    6307         errors=errors,
#    6308     )
#
# File ~\miniforge3\envs\pystudy_env\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4642 for axis, labels in axes.items():
#    4643     if labels is not None:
# -> 4644         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4646 if inplace:
#    4647     self._update_inplace(obj)
#
# File ~\miniforge3\envs\pystudy_env\Lib\site-packages\pandas\core\generic.py:4686, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4684         new_axis = axis.drop(labels, level=level, errors=errors)
#    4685     else:
# -> 4686         new_axis = axis.drop(labels, errors=errors)
#    4687     indexer = axis.get_indexer(new_axis)
#    4689 # Case for non-unique axis
#    4690 else:
#
# File ~\miniforge3\envs\pystudy_env\Lib\site-packages\pandas\core\indexes\base.py:7268, in Index.drop(self, labels, errors)
#    7266 if mask.any():
#    7267     if errors != "ignore":
# -> 7268         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7269     indexer = indexer[~mask]
#    7270 return self.delete(indexer)
#
# KeyError: '[3] not found in axis'

# %%
# 특정 조건을 만족하는 모든 행 삭제
df = df[df['final'] >= 60]
df
# Out:
#    name  midterm  final
# 0   홍길동       95   85.0
# 1  신사임당       85   80.0

# %% [markdown]
# ## 컬럼 추가/삭제

# %%
# df['phone'] = ['010-1234-1234', '010-5678-5678']
df.loc[:,'phone'] =  ['010-1234-1234', '010-5678-5678']
df
# Out:
#    name  midterm  final          phone
# 0   홍길동       95   85.0  010-1234-1234
# 1  신사임당       85   80.0  010-5678-5678

# %%
# 중간고사, 기말고사 평균 컬럼 (mean) 추가
df.loc[:, 'mean'] = (df['midterm']+df['final']) / 2
df
# Out:
#    name  midterm  final          phone  mean
# 0   홍길동       95   85.0  010-1234-1234  90.0
# 1  신사임당       85   80.0  010-5678-5678  82.5

# %%
# 컬럼 삭제
df = df[['name' , 'midterm', 'final']] # fancy indexing
df
# Out:
#    name  midterm  final
# 0   홍길동       95   85.0
# 1  신사임당       85   80.0

# %%
# ser|df.apply(함수)
# - 데이터프레임 또는 시리즈 객체의 각 요소에 함수를 적용할 때
# - 데이터 전처리 시 자주 사용

def pass_or_fail(value):
    return 'P' if value >= 60 else 'F'

df.loc[:,'avg'] = (df['midterm'] + df['final']) / 2
df.loc[2] = {'name': '이순신', 'midterm': 10, 'final': 30}

df.loc[:,'pass_or_fail'] = df['avg'].apply(pass_or_fail)
df
# Out:
#    name  midterm  final   avg pass_or_fail
# 0   홍길동       95   85.0  90.0            P
# 1  신사임당       85   80.0  82.5            P
# 2   이순신       10   30.0   NaN            F

# %%
def pass_or_fail2(record):
    avg = (record['midterm'] + record['final']) / 2
    return 'P' if avg >= 60 else 'F'

df.loc[:, 'pass_fail2'] = df.apply(pass_or_fail2, axis=1)
df
# Out:
#    name  midterm  final   avg pass_or_fail pass_fail2
# 0   홍길동       95   85.0  90.0            P          P
# 1  신사임당       85   80.0  82.5            P          P
# 2   이순신       10   30.0   NaN            F          F

# %% [markdown]
# ## 정렬

# %%
# csv를 읽어와 df 생성
df = pd.read_csv('./data/bank_client_information.csv')

# %%
# 지정된 컬럼 기준으로 내림차순
df.sort_values('Net Worth', ascending=False)
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
#
#    Years with Bank
# 5               26
# 6               11
# 7                3
# 3               10
# 1                6
# 2                7
# 9               13
# 0                5
# 4               22
# 8                1

# %%
# 메인 정렬 중 같은 값이 존재하면 추가로 정렬 지정
df.sort_values(['Net Worth', 'Years with Bank'], ascending = [True, False])
# Out:
#   First Name Last Name                    Email Postal Code  Net Worth  \
# 8     Joseph    Patton           daafeja@boh.jm     M6U 5U7    2629.13
# 4       Kate      Noor         kate@hotmail.com     K8N 5H6    5000.00
# 0      Bird      Steve           bird@gmail.com     N94 3M0    5000.00
# 9       Noah     Moran        guutodi@bigwoc.kw     K2D 4M9    8626.96
# 2       Nina    Keller          azikez@gahew.mr     S1T 4E6    9072.02
# 1       Noah     Small       nsmall@hotmail.com     N8S 14K   10000.00
# 3    Chanel      Steve         chanel@gmail.com     N7T 3E6   11072.02
# 7      Laila     Ahmed      Laila.a@hotmail.com     J8Y 3M0   20000.00
# 6       Heba    Ismail  heba.ismail@hotmail.com     K8Y 3M8   50000.00
# 5      Samer        Mo          samer@gmail.com     J7H 3HY  100000.00
#
#    Years with Bank
# 8                1
# 4               22
# 0                5
# 9               13
# 2                7
# 1                6
# 3               10
# 7                3
# 6               11
# 5               26

# %%
# 순쉬 부여하기
df.loc[:, 'Net Worth Rank'] = df['Net Worth'].rank(ascending = False).astype(int)
