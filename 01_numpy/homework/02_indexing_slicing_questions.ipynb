# %% [markdown]
# # [2] Numpy: ndarray 인덱싱 및 슬라이싱

# %% [markdown]
# ### [실습 1] 인덱싱과 슬라이싱
#
#
# 1. 배열 `arr`에서 1번째 열만 추출
# 2. 배열 `arr`에서 2번째 행, 3번째 열의 값을 출력
# 3. 배열 `arr`에서 2 번째 행부터 3 번째 행까지 선택하고, 0번째와 1번째 열만 추출
#
# ```python
# arr = np.array([[10, 20, 30], [40, 50, 60], [70, 80, 90]])
# ```

# %%
import numpy as np

# %%
arr = np.array([[10, 20, 30], [40, 50, 60], [70, 80, 90]])

# 1. 배열 `arr`에서 1번째 열만 추출
col1 = arr[:,0]
print(col1)

# 2. 배열 `arr`에서 1번째 행, 2번째 열의 값을 출력
col2 = arr[1,2]
print(col2)

# 3. 배열 `arr`에서 첫 번째 행부터 두 번째 행까지 선택하고, 0번째와 1번째 열만 추출
col3 = arr[1:3,0:2]
print(col3)
# Out:
# [10 40 70]
# 60
# [[40 50]
#  [70 80]]

# %% [markdown]
# ### [실습 2] 팬시 인덱싱과 불리언 인덱싱
#
#
# 아래 배열에서 팬시 인덱싱과 불리언 인덱싱을 사용하여 다음 작업을 수행하세요.
#
# 1. 팬시 인덱싱을 사용하여 배열의 0번째, 2번째, 4번째 요소를 출력
# 2. 배열의 값 중 50보다 큰 값만 추출
#
# ```python
# 	arr = np.array([10, 20, 30, 40, 50, 60, 70])
# ```

# %%
arr = np.array([10, 20, 30, 40, 50, 60, 70])

# 1. 팬시 인덱싱을 사용하여 배열의 0번째, 2번째, 4번째 요소를 출력
fancy_idx = arr[[0, 2, 4]]
print("팬시 인덱싱 결과: ", fancy_idx)

# 2. 배열의 값 중 50보다 큰 값만 추출
bool_idx = arr[arr > 50]
print("불리언 인덱싱 결과: ", bool_idx)
# Out:
# 팬시 인덱싱 결과:  [10 30 50]
# 불리언 인덱싱 결과:  [60 70]

# %% [markdown]
# ### [실습 3] 제품 판매 데이터 분석
#
#
# 어느 마트에서 판매되는 제품들의 월별 매출량이 아래와 같이 주어졌습니다. 각각의 행은 제품을 나타내고, 열은 각 월의 판매량을 나타냅니다.
#
# 1. 월별 판매량이 200개 이상인 제품의 판매량을 선택하라.
# 2. 3월(세 번째 열)의 판매량이 100개 이하인 제품의 1월과 2월 판매량을 추출하라.
# 3. 2월(두 번째 열)의 판매량이 150개 이상인 제품들의 전체 월별 판매량을 출력하라.
#
# ```python
# sales = np.array([[120, 150, 100],
#                   [80, 90, 110],
#                   [200, 180, 220],
#                   [50, 45, 70],
#                   [300, 320, 310]])
# ```

# %%
sales = np.array([[120, 150, 100],
                   [80, 90, 110],
                   [200, 180, 220],
                   [50, 45, 70],
                   [300, 320, 310]])

# 1. 판매량이 200개 이상인 값들을 선택
high_sales = sales[sales >= 200]
print("1. 200개 이상 판매량: ", high_sales)

# 2. 3월(인덱스 2) 판매량이 100개 이하인 제품의 1월, 2월 판매량 추출
mask = sales[:, 2] <= 100
result2 = sales[mask][:, 0:2]
print("2. 3월 판매량 100개 이하인 제품의 1,2월 판매량:\n", result2)

# 3. 2월(인덱스 1) 판매량이 150개 이상인 제품들의 전체 월별 판매량
mask3 = sales[:, 1] >= 200
result3 = sales[mask3]
print("3. 2월 판매량 200개 이상인 제품의 전체 월별 판매량:\n", result3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sales = np.array([[120, 150, 100],
#       2                    [80, 90, 110],
#       3                    [200, 180, 220],
#       4                    [50, 45, 70],
#
# NameError: name 'np' is not defined
